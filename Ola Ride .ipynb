# %%
import pandas as pd

# %%
booking=pd.read_csv(r'D:\Python\Bookings.csv')

# %%
booking.head()
# Out:
#                   Date      Time     Booking_ID        Booking_Status  \
# 0  2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1  2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2  2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3  2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4  2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# ...

# %%
booking.tail()
# Out:
#                        Date      Time     Booking_ID Booking_Status  \
# 103019  2024-07-31 09:06:00  09:06:00  CNR9488489435        Success
# 103020  2024-07-31 15:12:00  15:12:00  CNR3151743100        Success
# 103021  2024-07-31 13:59:00  13:59:00  CNR1286151233        Success
# 103022  2024-07-31 14:56:00  14:56:00  CNR2027162035        Success
# 103023  2024-07-31 13:57:00  13:57:00  CNR9770709721        Success
#
#        Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# 103019   CID371654   Prime Plus      Richmond Town        Varthur  245.0
# 103020   CID334158         Auto        Vijayanagar  Richmond Town   84.0
# 103021   CID113188    Prime SUV  Bannerghatta Road       JP Nagar   35.0
# 103022   CID118301        eBike        Indiranagar    Magadi Road  210.0
# 103023   CID217959         Auto             Ulsoor         Hennur  175.0
#
#         C_TAT Canceled_Rides_by_Customer Canceled_Rides_by_Driver  \
# ...

# %%
booking.shape
# Out:
# (103024, 20)

# %%
booking.describe()
# Out:
#               V_TAT         C_TAT  Booking_Value  Ride_Distance  \
# count  63967.000000  63967.000000  103024.000000  103024.000000
# mean     170.876952     84.873372     548.751883      14.189927
# std       80.803640     36.005100     536.541221      15.776270
# min       35.000000     25.000000     100.000000       0.000000
# 25%       98.000000     55.000000     242.000000       0.000000
# 50%      168.000000     85.000000     386.000000       8.000000
# 75%      238.000000    115.000000     621.000000      26.000000
# max      308.000000    145.000000    2999.000000      49.000000
#
#        Driver_Ratings  Customer_Rating
# count    63967.000000     63967.000000
# mean         3.997457         3.998313
# std          0.576834         0.578957
# min          3.000000         3.000000
# 25%          3.500000         3.500000
# 50%          4.000000         4.000000
# 75%          4.500000         4.500000
# max          5.000000         5.000000

# %%
booking.iloc[0:10,0:6]
# Out:
#                   Date      Time     Booking_ID        Booking_Status  \
# 0  2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1  2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2  2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3  2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4  2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# 5  2024-07-13 04:42:00  04:42:00  CNR8787177882               Success
# 6  2024-07-23 09:51:00  09:51:00  CNR3612067560               Success
# 7  2024-07-11 11:12:00  11:12:00  CNR5374902489    Canceled by Driver
# 8  2024-07-01 19:19:00  19:19:00  CNR5030602354      Driver Not Found
# 9  2024-07-18 01:31:00  01:31:00  CNR6328453219    Canceled by Driver
#
#   Customer_ID Vehicle_Type
# 0   CID713523  Prime Sedan
# 1   CID225428         Bike
# 2   CID270156    Prime SUV
# 3   CID581320        eBike
# 4   CID939555         Mini
# 5   CID802429         Mini
# ...

# %%
booking.loc[0:20,('Booking_ID','Booking_Status','Vehicle_Type')]
# Out:
#        Booking_ID        Booking_Status Vehicle_Type
# 0   CNR7153255142    Canceled by Driver  Prime Sedan
# 1   CNR2940424040               Success         Bike
# 2   CNR2982357879               Success    Prime SUV
# 3   CNR2395710036  Canceled by Customer        eBike
# 4   CNR1797421769               Success         Mini
# 5   CNR8787177882               Success         Mini
# 6   CNR3612067560               Success         Bike
# 7   CNR5374902489    Canceled by Driver   Prime Plus
# 8   CNR5030602354      Driver Not Found         Mini
# 9   CNR6328453219    Canceled by Driver         Auto
# 10  CNR4787583516               Success   Prime Plus
# 11  CNR7943634301               Success   Prime Plus
# 12  CNR4524472111               Success         Auto
# 13  CNR3914552212    Canceled by Driver         Auto
# 14  CNR8181602032               Success         Bike
# 15  CNR8090918544               Success         Bike
# 16  CNR3211335290      Driver Not Found         Mini
# ...

# %%
booking.head()
# Out:
#                   Date      Time     Booking_ID        Booking_Status  \
# 0  2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1  2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2  2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3  2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4  2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# ...

# %%
booking.drop('Vehicle Images',axis=1) #for coloumn axis=1
# Out:
#                        Date      Time     Booking_ID        Booking_Status  \
# 0       2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1       2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2       2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3       2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4       2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                     ...       ...            ...                   ...
# 103019  2024-07-31 09:06:00  09:06:00  CNR9488489435               Success
# 103020  2024-07-31 15:12:00  15:12:00  CNR3151743100               Success
# 103021  2024-07-31 13:59:00  13:59:00  CNR1286151233               Success
# 103022  2024-07-31 14:56:00  14:56:00  CNR2027162035               Success
# 103023  2024-07-31 13:57:00  13:57:00  CNR9770709721               Success
#
# ...

# %%
booking.drop([0],axis=0)   #for rows axis= 0
# Out:
#                        Date      Time     Booking_ID        Booking_Status  \
# 1       2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2       2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3       2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4       2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# 5       2024-07-13 04:42:00  04:42:00  CNR8787177882               Success
# ...                     ...       ...            ...                   ...
# 103019  2024-07-31 09:06:00  09:06:00  CNR9488489435               Success
# 103020  2024-07-31 15:12:00  15:12:00  CNR3151743100               Success
# 103021  2024-07-31 13:59:00  13:59:00  CNR1286151233               Success
# 103022  2024-07-31 14:56:00  14:56:00  CNR2027162035               Success
# 103023  2024-07-31 13:57:00  13:57:00  CNR9770709721               Success
#
# ...

# %%
booking['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Prime Sedan    14877
# eBike          14816
# Auto           14755
# Prime Plus     14707
# Bike           14662
# Prime SUV      14655
# Mini           14552
# Name: count, dtype: int64

# %%
booking['Booking_Status'].value_counts()
# Out:
# Booking_Status
# Success                 63967
# Canceled by Driver      18434
# Canceled by Customer    10499
# Driver Not Found        10124
# Name: count, dtype: int64

# %%
booking.sort_values(by='Driver_Ratings')
# Out:
#                        Date      Time     Booking_ID      Booking_Status  \
# 7855    2024-07-15 22:56:00  22:56:00  CNR4117241946             Success
# 86129   2024-07-19 15:34:00  15:34:00  CNR3863160134             Success
# 12      2024-07-27 13:18:00  13:18:00  CNR4524472111             Success
# 25112   2024-07-02 05:40:00  05:40:00  CNR7217066922             Success
# 97478   2024-07-18 07:42:00  07:42:00  CNR5367383801             Success
# ...                     ...       ...            ...                 ...
# 103008  2024-07-31 14:38:00  14:38:00  CNR9936519920    Driver Not Found
# 103010  2024-07-31 07:28:00  07:28:00  CNR2746062760  Canceled by Driver
# 103014  2024-07-31 17:11:00  17:11:00  CNR8606968614    Driver Not Found
# 103015  2024-07-31 17:43:00  17:43:00  CNR1504131542  Canceled by Driver
# 103016  2024-07-31 09:20:00  09:20:00  CNR3395373353    Driver Not Found
#
#        Customer_ID Vehicle_Type Pickup_Location     Drop_Location  V_TAT  \
# ...
